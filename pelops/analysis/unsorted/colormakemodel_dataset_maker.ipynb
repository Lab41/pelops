# %%
import os
from collections import defaultdict
from itertools import product
import json
from random import shuffle
import glob
import shutil
import tqdm
import json

# %%
color_file = './colors'
type_file = './carTypes.csv'
allFiles = '/local_data/dgrossman/dgCars/allFiles.no.unicode'

# %%
colors = list()
a = open(color_file,'r')
for line in a:
    colors.append(line.strip().lower())
a.close()

# %%
colors
# Out:
# ['black',
#  'blue',
#  'brown',
#  'gray',
#  'green',
#  'orange',
#  'red',
#  'silver',
#  'white',
#  'yellow']

# %%
def make_key(first,second):
    return '{0}:{1}'.format(first,second)
def make_class(c,s,t,m):
    if c == '1': 
        return 'car'
    if s == '1': 
        return 'suv'
    if t == '1': 
        return 'truck'
    if m == '1': 
        return 'minivan'
    return 'unknown'
class_types =['car','suv','truck','minivan']

# %%
#car2type=defaultdict(set)
car2type = {}
a = open(type_file,'r')
for line in a:
    make,model,car,suv,truck,minivan =line.strip().lower().split(',')
    value = make_class(car,suv,truck,minivan)
    key = make_key(make,model)
    #car2type[key].add(value)
    car2type[key] = value
a.close()

# %%
color2dir = {}
for num,col in enumerate(colors):
    color2dir[col]= num

color2dir
# Out:
# {'black': 0,
#  'blue': 1,
#  'brown': 2,
#  'gray': 3,
#  'green': 4,
#  'orange': 5,
#  'red': 6,
#  'silver': 7,
#  'white': 8,
#  'yellow': 9}

# %%
car2type
# Out:
# {'honda:accord_crosstour': 'car',
#  'dodge:ram_van_2500': 'minivan',
#  'mercedes-benz:slk55_amg': 'car',
#  'pontiac:firefly': 'car',
#  'isuzu:rodeo': 'suv',
#  'maserati:granturismo': 'car',
#  'pontiac:turbo_firefly': 'car',
#  'pontiac:firebird_trans_am': 'car',
#  'pontiac:g8': 'car',
#  'acura:vigor': 'car',
#  'mercedes-benz:400sel': 'car',
#  'ford:fiesta': 'car',
#  'mazda:b-series': 'truck',
#  'ford:c-max_hybrid': 'car',
#  'saturn:aura': 'car',
#  'bmw:330': 'car',
#  'audi:4000s_quattro': 'car',
#  'mitsubishi:lancer_evolution': 'car',
#  'audi:a5': 'car',
#  'saturn:astra': 'car',
#  'chevrolet:cobalt': 'car',
#  'buick:skylark': 'car',
#  'cadillac:allante': 'car',
#  'nissan:350z_roadster': 'car',
#  'hummer:h2_suv': 'suv',
#  'rolls-royce:phantom': 'car',
#  'oldsmobile:cutlass_supreme': 'car',
#  'pontiac:grand_prix_turbo': 'car',
#  'gmc:ev1': 'car',
#  'dodge:ram_van_3500': 'minivan',
#  'buick:terraza': 'minivan',
#  'chrysler:imperial': 'car',
#  'mazda:mazda5': 'car',
#  'audi:a8': 'car',
#  'mitsubishi:mighty_max': 'truck',
#  'nissan:armada': 'suv',
#  'ford:thunderbird': 'car',
#  'acura:tsx': 'car',
#  'dodge:grand_caravan': 'minivan',
#  'bentley:continental_gtc': 'car',
#  'mitsubishi:3000gt': 'car',
#  'mazda:b2600': 'truck',
#  'chevrolet:tahoe': 'suv',
#  'ford:bronco_ii': 'suv',
#  'chrysler:300m': 'car',
#  'chevrolet:suburban_2500': 'suv',
#  'bmw:z3': 'car',
#  'porsche:914': 'car',
#  'audi:5000s': 'car',
#  'gmc:sierra': 'truck',
#  'saturn:sky': 'car',
#  'chevrolet:g-series_2500': 'minivan',
#  'nissan:pathfinder_armada': 'suv',
#  'ford:gt500': 'car',
#  'jaguar:xk': 'car',
#  'volkswagen:vanagon': 'minivan',
#  'buick:rainier': 'suv',
#  'chrysler:pacifica': 'minivan',
#  'mercedes-benz:gl-class': 'suv',
#  'chevrolet:suburban_1500': 'suv',
#  'smart:fortwo': 'car',
#  'plymouth:sundance': 'car',
#  'ford:transit_connect': 'minivan',
#  'bmw:325': 'car',
#  'mazda:protege': 'car',
#  'ram:2500': 'truck',
#  'mitsubishi:outlander_sport': 'suv',
#  'toyota:matrix': 'car',
#  'mercedes-benz:sls-class': 'car',
#  'mercury:grand_marquis': 'car',
#  'toyota:camry': 'car',
#  'lincoln:mkz': 'car',
#  'gmc:vandura_2500': 'minivan',
#  'lamborghini:diablo': 'car',
#  'ford:zx2': 'car',
#  'mazda:glc': 'car',
#  'austin:mini_cooper': 'car',
#  'mercedes-benz:cls-class': 'car',
#  'honda:cr-v': 'suv',
#  'mitsubishi:raider': 'truck',
#  'chrysler:town_&_country': 'minivan',
#  'infiniti:g25': 'car',
#  'lexus:sc': 'car',
#  'maserati:coupe': 'car',
#  'spyker:c8_double_12_s': 'car',
#  'chevrolet:avalanche_1500': 'suv',
#  'toyota:fj_cruiser': 'suv',
#  'ford:club_wagon': 'minivan',
#  'nissan:240sx': 'car',
#  'toyota:tacoma': 'truck',
#  'chevrolet:apv': 'minivan',
#  'ford:ltd_crown_victoria': 'car',
#  'aston_martin:v8_vantage_s': 'car',
#  'chevrolet:ssr': 'car',
#  'tesla:model_s': 'car',
#  'land_rover:sterling': 'suv',
#  'lexus:gx': 'suv',
#  'bmw:x5': 'suv',
#  'mitsubishi:excel': 'car',
#  'porsche:924_s': 'car',
#  'saab:9-7x': 'suv',
#  'gmc:savana': 'minivan',
#  'jeep:wrangler': 'suv',
#  'lincoln:mark_vii': 'car',
#  'gmc:rally_wagon_g2500': 'minivan',
#  'audi:s6': 'car',
#  'land_rover:range_rover_sport': 'suv',
#  'chevrolet:avalanche_2500': 'suv',
#  'toyota:prius_plug-in_hybrid': 'car',
#  'spyker_cars:c8': 'car',
#  'chevrolet:monza': 'car',
#  'bugatti:veyron': 'car',
#  'bmw:1_series': 'car',
#  'bentley:arnage': 'car',
#  'toyota:tercel': 'car',
#  'mazda:cx-9': 'suv',
#  'plymouth:laser': 'car',
#  'mercedes-benz:clk-class': 'car',
#  'volkswagen:quantum': 'car',
#  'mitsubishi:montero_sport': 'suv',
#  'cadillac:fleetwood': 'car',
#  'dodge:shadow': 'car',
#  'volkswagen:routan': 'minivan',
#  'chevrolet:g-series_3500': 'minivan',
#  'volkswagen:rio': 'car',
#  'mercedes-benz:sl65_amg': 'car',
#  'honda:fit': 'car',
#  'geo:metro': 'car',
#  'ferrari:f430': 'car',
#  'chevrolet:3500': 'truck',
#  'ford:explorer_sport': 'suv',
#  'geo:prizm': 'car',
#  'volkswagen:fox': 'car',
#  'audi:4000': 'car',
#  'suzuki:xl-7': 'suv',
#  'chevrolet:g-series_g': 'minivan',
#  'subaru:b9_tribeca': 'suv',
#  'mazda:familia': 'car',
#  'maserati:430': 'car',
#  'ferrari:f430_spider': 'car',
#  'maserati:gran_sport': 'car',
#  'volkswagen:jetta_iii': 'car',
#  'lincoln:mark_lt': 'truck',
#  'fiat:500': 'car',
#  'jaguar:xj_series': 'car',
#  'ford:focus': 'car',
#  'subaru:outback': 'suv',
#  'mercedes-benz:c-class': 'car',
#  'dodge:ram': 'truck',
#  'mitsubishi:challenger': 'suv',
#  'suzuki:forenza': 'car',
#  'honda:cr-x': 'car',
#  'cadillac:sts-v': 'car',
#  'toyota:camry_hybrid': 'car',
#  'lotus:esprit_turbo': 'car',
#  'ford:courier': 'suv',
#  'mercedes-benz:500sec': 'car',
#  'audi:rs_6': 'car',
#  'suzuki:esteem': 'car',
#  'nissan:nv2500': 'minivan',
#  'jeep:patriot': 'suv',
#  'plymouth:neon': 'car',
#  'audi:a7': 'car',
#  'daewoo:leganza': 'car',
#  'kia:soul': 'car',
#  'bmw:3_series': 'car',
#  'mini:cooper': 'car',
#  'honda:civic_gx': 'car',
#  'volvo:s40': 'car',
#  'chrysler:200': 'car',
#  'chevrolet:vega': 'car',
#  'dodge:durango': 'suv',
#  'mitsubishi:diamante': 'car',
#  'mercury:montego': 'car',
#  'toyota:cressida': 'car',
#  'mercedes-benz:sprinter_2500': 'minivan',
#  'chevrolet:lumina': 'car',
#  'mitsubishi:sigma': 'car',
#  'chevrolet:lumina_apv': 'car',
#  'dodge:caravan': 'minivan',
#  'suzuki:xl7': 'suv',
#  'lincoln:navigator_l': 'suv',
#  'ford:freestyle': 'car',
#  'audi:rs_4': 'car',
#  'plymouth:voyager': 'minivan',
#  'mercedes-benz:sprinter_3500': 'minivan',
#  'infiniti:j': 'suv',
#  'chevrolet:blazer': 'suv',
#  'acura:rl': 'car',
#  'nissan:altima': 'car',
#  'ford:taurus': 'car',
#  'oldsmobile:silhouette': 'minivan',
#  'bmw:545': 'car',
#  'toyota:echo': 'car',
#  'dodge:ram_3500_club': 'truck',
#  'pontiac:lemans': 'car',
#  'mercedes-benz:m-class': 'suv',
#  'porsche:panamera': 'car',
#  'pontiac:g3': 'car',
#  'ferrari:ff': 'car',
#  'pontiac:trans_sport': 'minivan',
#  'toyota:ipsum': 'minivan',
#  'chevrolet:cruze': 'car',
#  'acura:rdx': 'car',
#  'chevrolet:beretta': 'car',
#  'cadillac:xlr-v': 'car',
#  'acura:rsx': 'car',
#  'gmc:envoy': 'suv',
#  'hyundai:tucson': 'suv',
#  'aston_martin:db9': 'car',
#  'isuzu:i-280': 'truck',
#  'chrysler:300c': 'car',
#  'infiniti:jx': 'suv',
#  'lamborghini:murcielago_lp640': 'car',
#  'infiniti:m': 'car',
#  'hyundai:santa_fe': 'suv',
#  'buick:lucerne': 'car',
#  'mitsubishi:endeavor': 'suv',
#  'pontiac:parisienne': 'car',
#  'infiniti:g37': 'car',
#  'subaru:legacy': 'car',
#  'ford:taurus_x': 'car',
#  'mitsubishi:expo': 'suv',
#  'bmw:z8': 'car',
#  'mazda:929': 'car',
#  'chevrolet:express_1500': 'minivan',
#  'infiniti:g': 'car',
#  'cadillac:cts': 'car',
#  'hyundai:xg350': 'car',
#  'saturn:vue': 'suv',
#  'suzuki:daewoo_magnus': 'car',
#  'dodge:d350_club': 'truck',
#  'pontiac:solstice': 'car',
#  'nissan:350z': 'car',
#  'dodge:intrepid': 'car',
#  'spyker:c8_spyder': 'car',
#  'ford:e-350_super_duty_van': 'truck',
#  'mercedes-benz:300se': 'car',
#  'nissan:xterra': 'suv',
#  'nissan:frontier': 'truck',
#  'porsche:911': 'car',
#  'bmw:z4': 'car',
#  'audi:r8': 'car',
#  'audi:80/90': 'car',
#  'audi:4000cs_quattro': 'car',
#  'isuzu:hombre': 'truck',
#  'geo:tracker': 'suv',
#  'mitsubishi:i-miev': 'car',
#  'volvo:v90': 'car',
#  'cadillac:sts': 'car',
#  'subaru:svx': 'car',
#  'mercedes-benz:500sl': 'car',
#  'dodge:dakota': 'truck',
#  'chevrolet:uplander': 'minivan',
#  'chevrolet:s10': 'truck',
#  'chevrolet:2500': 'truck',
#  'dodge:spirit': 'car',
#  'mercury:sable': 'car',
#  'ford:edge': 'suv',
#  'mg:mgb': 'car',
#  'isuzu:amigo': 'suv',
#  'chevrolet:prizm': 'car',
#  'volvo:xc70': 'suv',
#  'aston_martin:v12_vantage': 'car',
#  'mini:mini': 'car',
#  'dodge:d250': 'truck',
#  'gmc:yukon_xl_2500': 'suv',
#  'mitsubishi:tredia': 'car',
#  'buick:verano': 'car',
#  'mini:countryman': 'car',
#  'audi:tt': 'car',
#  'gmc:2500_club_coupe': 'truck',
#  'nissan:gt-r': 'car',
#  'volvo:940': 'car',
#  'chevrolet:k5_blazer': 'suv',
#  'volkswagen:eurovan': 'minivan',
#  'lamborghini:murcielago': 'car',
#  'bmw:750': 'car',
#  'chevrolet:g-series_1500': 'minivan',
#  'mazda:protege5': 'car',
#  'lincoln:town_car': 'car',
#  'mazda:mazda6': 'car',
#  'mercedes-benz:g55_amg': 'suv',
#  'chevrolet:volt': 'car',
#  'chevrolet:traverse': 'suv',
#  'cadillac:brougham': 'car',
#  'dodge:ram_1500_club': 'truck',
#  'dodge:dynasty': 'car',
#  'toyota:yaris': 'car',
#  'chevrolet:malibu': 'car',
#  'dodge:avenger': 'car',
#  'mazda:b-series_plus': 'truck',
#  'hyundai:genesis_coupe': 'car',
#  'bentley:brooklands': 'car',
#  'ford:th!nk': 'car',
#  'oldsmobile:ciera': 'car',
#  'toyota:sienna': 'minivan',
#  'honda:civic_si': 'car',
#  'daewoo:nubira': 'car',
#  'maserati:228': 'car',
#  'chrysler:crossfire': 'car',
#  'saab:9-2x': 'car',
#  'gmc:yukon': 'suv',
#  'volkswagen:cabriolet': 'car',
#  'nissan:pathfinder': 'suv',
#  'mercury:marauder': 'car',
#  'gmc:vandura_g2500': 'minivan',
#  'rambler:classic': 'car',
#  'chrysler:cirrus': 'car',
#  'infiniti:ex': 'car',
#  'nissan:rogue': 'suv',
#  'lincoln:mark_viii': 'car',
#  'mini:clubman': 'car',
#  'land_rover:range_rover_classic': 'suv',
#  'saab:900': 'car',
#  'land_rover:defender_ice_edition': 'suv',
#  'jeep:compass': 'suv',
#  'cadillac:xlr': 'car',
#  'lotus:evora': 'car',
#  'bentley:continental_flying_spur': 'car',
#  'volvo:s80': 'car',
#  'nissan:titan': 'truck',
#  'chevrolet:caprice': 'car',
#  'volvo:v40': 'car',
#  'volkswagen:tiguan': 'suv',
#  'bmw:5_series': 'car',
#  'saab:42616': 'car',
#  'plymouth:fury': 'car',
#  'land_rover:lr2': 'suv',
#  'subaru:alcyone_svx': 'car',
#  'mercury:marquis': 'car',
#  'nissan:leaf': 'car',
#  'pontiac:gto': 'car',
#  'gmc:savana_cargo_van': 'minivan',
#  'mitsubishi:space': 'car',
#  'volkswagen:scirocco': 'car',
#  'dodge:ram_wagon_b350': 'minivan',
#  'mercedes-benz:500e': 'car',
#  'chevrolet:venture': 'car',
#  'mitsubishi:expo_lrv': 'suv',
#  'fillmore:fillmore': 'minivan',
#  'mercedes-benz:slr_mclaren': 'car',
#  'plymouth:grand_voyager': 'minivan',
#  'volkswagen:beetle': 'car',
#  'bmw:x5_m': 'suv',
#  'bmw:650': 'car',
#  'gmc:vandura_g1500': 'minivan',
#  'honda:ridgeline': 'truck',
#  'pontiac:g6': 'car',
#  'mazda:mazda6_sport': 'car',
#  'lincoln:navigator': 'suv',
#  'pontiac:fiero': 'car',
#  'plymouth:volare': 'car',
#  'porsche:928': 'car',
#  'isuzu:hombre_space': 'truck',
#  'ram:1500': 'truck',
#  'gmc:canyon': 'truck',
#  'mitsubishi:montero': 'suv',
#  'mercedes-benz:w123': 'car',
#  'lincoln:mkt': 'suv',
#  'ford:explorer_sport_trac': 'suv',
#  'gmc:suburban_1500': 'truck',
#  'ferrari:california': 'car',
#  'pontiac:monterey': 'car',
#  'lamborghini:gallardo': 'car',
#  'dodge:daytona': 'car',
#  'jaguar:xf': 'car',
#  'pontiac:grand_am': 'car',
#  'isuzu:i-350': 'truck',
#  'gmc:sierra_denali': 'truck',
#  'gmc:yukon_denali': 'suv',
#  'cadillac:escalade_esv': 'suv',
#  'ford:flex': 'suv',
#  'audi:riolet': 'car',
#  'infiniti:q': 'car',
#  'suzuki:aerio': 'car',
#  'tesla:roadster': 'car',
#  'mercedes-benz:e-class': 'car',
#  'volkswagen:type_2': 'minivan',
#  'mazda:b2500': 'truck',
#  'aston_martin:dbs': 'car',
#  'acura:nsx': 'car',
#  'kia:mentor': 'car',
#  'saturn:outlook': 'suv',
#  'bmw:645': 'car',
#  'volvo:c30': 'car',
#  'suzuki:samurai': 'suv',
#  'lexus:rx_hybrid': 'car',
#  'mitsubishi:eclipse': 'car',
#  'kia:carens': 'car',
#  'subaru:forester': 'suv',
#  'toyota:t100_xtra': 'truck',
#  'chevrolet:citation': 'car',
#  'bentley:azure': 'car',
#  'bmw:m3': 'car',
#  'mercedes-benz:sl-class': 'car',
#  'ford:gt': 'car',
#  'dodge:ram_2500': 'truck',
#  'jeep:cherokee': 'suv',
#  'volkswagen:new_beetle': 'car',
#  'ford:excursion': 'suv',
#  'ford:explorer': 'suv',
#  'chevrolet:metro': 'car',
#  'plymouth:colt_vista': 'car',
#  'chevrolet:silverado_3500': 'truck',
#  'dodge:ramcharger': 'suv',
#  'chrysler:crossfire_roadster': 'car',
#  'acura:slx': 'suv',
#  'gmc:rally_wagon_1500': 'minivan',
#  'audi:100': 'car',
#  'plymouth:acclaim': 'car',
#  'gmc:savana_2500': 'minivan',
#  'pontiac:montana': 'minivan',
#  'toyota:celica': 'car',
#  'land_rover:discovery': 'suv',
#  'plymouth:horizon': 'car',
#  'land_rover:defender': 'suv',
#  'buick:enclave': 'suv',
#  'lexus:ls': 'car',
#  'dodge:ram_wagon_b250': 'minivan',
#  'gmc:sierra_3500': 'truck',
#  'ford:bronco': 'suv',
#  'volvo:xc60': 'suv',
#  'ram:dakota': 'truck',
#  'buick:century': 'car',
#  'dodge:omni': 'car',
#  'audi:s5': 'car',
#  'audi:a4': 'car',
#  'pontiac:6000': 'car',
#  'lexus:hs': 'car',
#  'bentley:continental_gt': 'car',
#  'lincoln:ls': 'car',
#  'isuzu:vehicross': 'suv',
#  'toyota:rav4': 'suv',
#  'subaru:impreza_wrx': 'car',
#  'dodge:ram_van_b150': 'minivan',
#  'mazda:tribute': 'suv',
#  'mercury:tracer': 'car',
#  'kia:rondo': 'car',
#  'suzuki:kizashi': 'car',
#  'gmc:sonoma': 'truck',
#  'corbin:sparrow': 'car',
#  'land_rover:discovery_series_ii': 'suv',
#  'kia:rio5': 'car',
#  'gmc:vandura_3500': 'minivan',
#  'ford:expedition': 'suv',
#  'mercedes-benz:cl-class': 'car',
#  'lamborghini:reventon': 'car',
#  'dodge:journey': 'suv',
#  'lincoln:mks': 'car',
#  'peugeot:207': 'car',
#  'mazda:navajo': 'suv',
#  'ford:f-350_super_duty': 'truck',
#  'pontiac:sunfire': 'car',
#  'saturn:l-series': 'car',
#  'hyundai:veloster': 'car',
#  'dodge:neon': 'car',
#  'hummer:h1': 'suv',
#  'lotus:elise': 'car',
#  'ford:ltd': 'car',
#  'shelby:gt350': 'car',
#  'pontiac:firebird': 'car',
#  'ford:e250': 'truck',
#  'infiniti:ipl_g': 'car',
#  'infiniti:qx': 'suv',
#  'hyundai:accent': 'car',
#  'lexus:ct': 'car',
#  'mercedes-benz:190e': 'car',
#  'nissan:maxima': 'car',
#  'hyundai:elantra': 'car',
#  'scion:iq': 'car',
#  'chrysler:pt_cruiser': 'car',
#  'maserati:quattroporte': 'car',
#  'ferrari:458_italia': 'car',
#  'shelby:gt500': 'car',
#  'jeep:commander': 'suv',
#  'lexus:ls_hybrid': 'car',
#  'gmc:vandura_g3500': 'minivan',
#  'suzuki:vitara': 'suv',
#  'buick:special': 'car',
#  'mitsubishi:gto': 'car',
#  'ford:model_t': 'car',
#  'volvo:740': 'car',
#  'ford:escort': 'car',
#  'lotus:esprit': 'car',
#  'gmc:acadia': 'suv',
#  'bmw:m_roadster': 'car',
#  'chevrolet:sportvan_g30': 'minivan',
#  'chevrolet:monte_carlo': 'car',
#  'bmw:550': 'car',
#  'ford:e-350_super_duty': 'truck',
#  'bmw:m': 'car',
#  'mitsubishi:mirage': 'car',
#  'chrysler:300': 'car',
#  'gmc:yukon_xl_1500': 'suv',
#  'holden:monaro': 'car',
#  'buick:coachbuilder': 'car',
#  'volvo:v50': 'car',
#  'kia:amanti': 'car',
#  'mitsubishi:mighty_max_macro': 'truck',
#  'lotus:elan': 'car',
#  'mercedes-benz:600sel': 'car',
#  'plymouth:colt': 'car',
#  'pontiac:tempest': 'car',
#  'nissan:datsun/nissan_z-car': 'car',
#  'oldsmobile:alero': 'car',
#  'chevrolet:sportvan_g': 'minivan',
#  'infiniti:i': 'car',
#  'mclaren:mp4-12c': 'car',
#  'toyota:highlander_hybrid': 'suv',
#  'chevrolet:camaro': 'car',
#  'gmc:1500_club_coupe': 'truck',
#  'gmc:savana_3500': 'minivan',
#  'gmc:sierra_1500': 'truck',
#  'gmc:sierra_hybrid': 'truck',
#  'nissan:versa': 'car',
#  'audi:allroad': 'car',
#  'chevrolet:sonic': 'car',
#  'subaru:impreza': 'car',
#  'dodge:caliber': 'car',
#  'lexus:is_f': 'car',
#  'lotus:exige': 'car',
#  'chevrolet:g-series_g30': 'minivan',
#  'saturn:relay': 'minivan',
#  'ford:exp': 'car',
#  'maybach:landaulet': 'car',
#  'toyota:prius': 'car',
#  'mercedes-benz:g-class': 'suv',
#  'subaru:outback_sport': 'suv',
#  'ford:crown_victoria': 'car',
#  'land_rover:lr3': 'suv',
#  'nissan:nv1500': 'minivan',
#  'saab:9-5': 'car',
#  'buick:lacrosse': 'car',
#  'chrysler:aspen': 'suv',
#  'chevrolet:silverado': 'truck',
#  'mitsubishi:pajero': 'suv',
#  'gmc:sierra_3500hd': 'truck',
#  'mercury:villager': 'minivan',
#  'audi:v8': 'car',
#  'jaguar:x-type': 'suv',
#  'holden:vs_commodore': 'car',
#  'ford:contour': 'car',
#  'suzuki:cultus': 'car',
#  'mercury:mariner': 'suv',
#  'gmc:3500': 'truck',
#  'bmw:530': 'car',
#  'alfa_romeo:164': 'car',
#  'renault:alliance': 'car',
#  'toyota:tundramax': 'truck',
#  'dodge:ram_wagon_b150': 'minivan',
#  'ford:fusion': 'car',
#  'cadillac:cts-v': 'car',
#  'cadillac:escalade_ext': 'suv',
#  'dodge:charger': 'car',
#  'merkur:xr4ti': 'car',
#  'chrysler:new_yorker': 'car',
#  'suzuki:sj': 'suv',
#  'buick:somerset': 'car',
#  'scion:xb': 'car',
#  'gmc:yukon_xl': 'suv',
#  'nissan:280zx': 'car',
#  'mitsubishi:truck': 'truck',
#  'dodge:d150': 'truck',
#  'maserati:biturbo': 'car',
#  'isuzu:space': 'truck',
#  'bmw:760': 'car',
#  'audi:a6': 'car',
#  'dodge:ram_50': 'truck',
#  'alfa_romeo:spider': 'car',
#  'bmw:x3': 'suv',
#  'chevrolet:hhr': 'suv',
#  'bmw:745': 'car',
#  'bmw:z4_m': 'car',
#  'mercedes-benz:400e': 'car',
#  'ford:f-series_super_duty': 'truck',
#  'honda:insight': 'car',
#  'lamborghini:aventador': 'car',
#  'audi:s8': 'car',
#  'toyota:sequoia': 'suv',
#  'audi:a3': 'car',
#  'ferrari:612_scaglietti': 'car',
#  'honda:civic': 'car',
#  'mercedes-benz:300sl': 'car',
#  'hummer:h3': 'suv',
#  'subaru:brz': 'car',
#  'cadillac:eldorado': 'car',
#  'buick:estate': 'car',
#  'ford:e350': 'truck',
#  'studebaker:avanti': 'car',
#  'cadillac:escalade': 'suv',
#  'buick:riviera': 'car',
#  'oldsmobile:regency': 'car',
#  'suzuki:daewoo_lacetti': 'car',
#  'austin:mini': 'car',
#  'land_rover:range_rover_evoque': 'suv',
#  'buick:regal': 'car',
#  'mercedes-benz:sls_amg': 'car',
#  'chevrolet:suburban': 'suv',
#  'cadillac:dts': 'car',
#  'gmc:sonoma_club_coupe': 'truck',
#  'rolls-royce:ghost': 'car',
#  'acura:integra': 'car',
#  'bmw:m5': 'car',
#  'mazda:mazda6_5-door': 'car',
#  'dodge:viper': 'car',
#  'ford:econoline_e250': 'minivan',
#  'dodge:magnum': 'car',
#  'pontiac:chevette': 'car',
#  'oldsmobile:lss': 'car',
#  'morgan:aero_8': 'car',
#  'subaru:leone': 'car',
#  'hyundai:azera': 'car',
#  'dodge:challenger': 'car',
#  'chevrolet:corvair_500': 'car',
#  'mercedes-benz:cl65_amg': 'car',
#  'buick:roadmaster': 'car',
#  'chevrolet:impala_ss': 'car',
#  'gmc:envoy_xuv': 'suv',
#  'gmc:jimmy': 'suv',
#  'lincoln:continental_mark_vii': 'car',
#  'toyota:previa': 'minivan',
#  'citroen:cx': 'car',
#  'saturn:s-series': 'car',
#  'ford:aerostar': 'minivan',
#  'ferrari:430_scuderia': 'car',
#  'land_rover:lr4': 'suv',
#  'ford:f150': 'truck',
#  'ford:f-250_super_duty': 'truck',
#  'maserati:gransport': 'car',
#  'aston_martin:vanquish_s': 'car',
#  'lexus:es': 'car',
#  'lexus:is-f': 'car',
#  'chrysler:concorde': 'car',
#  'ford:mustang': 'car',
#  'bentley:mulsanne': 'car',
#  'dodge:ram_3500': 'truck',
#  'hyundai:equus': 'car',
#  'ford:escort_zx2': 'car',
#  'dodge:ram_2500_club': 'truck',
#  'audi:rs6': 'car',
#  'mitsubishi:lancer': 'car',
#  'mazda:mx-3': 'car',
#  'chevrolet:avalanche': 'suv',
#  'honda:s2000': 'car',
#  'jeep:comanche': 'truck',
#  'ram:3500': 'truck',
#  'gmc:envoy_xl': 'suv',
#  'mitsubishi:l300': 'minivan',
#  'nissan:juke': 'suv',
#  'volkswagen:eos': 'car',
#  'kia:rio': 'car',
#  'chevrolet:silverado_1500': 'truck',
#  'mercury:mountaineer': 'suv',
#  'ford:fairlane': 'car',
#  'hyundai:scoupe': 'car',
#  'pontiac:daewoo_kalos': 'car',
#  'porsche:boxster': 'car',
#  'chevrolet:sportvan_g10': 'minivan',
#  'land_rover:defender_90': 'suv',
#  'mazda:millenia': 'car',
#  'chevrolet:silverado_3500hd': 'truck',
#  'audi:coupe_quattro': 'car',
#  'bmw:6_series': 'car',
#  'mercedes-benz:600sec': 'car',
#  'eagle:premier': 'car',
#  'hyundai:tiburon': 'car',
#  'suzuki:swift': 'car',
#  'nissan:murano': 'suv',
#  'chevrolet:cavalier': 'car',
#  'hummer:h3t': 'suv',
#  'toyota:prius_v': 'car',
#  'ford:torino': 'car',
#  'dodge:nitro': 'suv',
#  'porsche:cayman': 'car',
#  'hyundai:veracruz': 'suv',
#  'chevrolet:express_3500': 'minivan',
#  'chevrolet:colorado': 'truck',
#  'suzuki:sx4': 'car',
#  'volkswagen:rabbit': 'car',
#  'saab:42618': 'car',
#  'dodge:colt': 'car',
#  'nissan:sentra': 'car',
#  'hyundai:entourage': 'minivan',
#  'mercedes-benz:s-class': 'car',
#  'ford:e-series': 'truck',
#  'aston_martin:rapide': 'car',
#  'dodge:aries': 'car',
#  'dodge:d150_club': 'truck',
#  'nissan:stanza': 'car',
#  'scion:xa': 'car',
#  'pontiac:bonneville': 'car',
#  'subaru:brat': 'truck',
#  'audi:80': 'car',
#  'aston_martin:virage': 'car',
#  'gmc:sierra_2500hd': 'truck',
#  'honda:cr-z': 'car',
#  'toyota:tundra': 'truck',
#  'porsche:968': 'car',
#  'mazda:mazda3': 'car',
#  'subaru:loyale': 'car',
#  'land_rover:freelander': 'suv',
#  'oldsmobile:achieva': 'car',
#  'pontiac:safari': 'car',
#  'audi:q5': 'car',
#  'mitsubishi:rvr': 'suv',
#  'isuzu:oasis': 'minivan',
#  'isuzu:trooper': 'suv',
#  'mazda:mazda2': 'car',
#  'mercedes-benz:300te': 'car',
#  'nissan:quest': 'minivan',
#  'chevrolet:corvette': 'car',
#  'toyota:supra': 'car',
#  'volkswagen:touareg': 'suv',
#  'plymouth:breeze': 'car',
#  'kia:sedona': 'minivan',
#  'chevrolet:s10_blazer': 'suv',
#  'gmc:terrain': 'suv',
#  'nissan:370z': 'car',
#  'oldsmobile:cutlass': 'car',
#  'suzuki:sj_410': 'suv',
#  'mazda:mpv': 'minivan',
#  'dodge:viper_rt/10': 'car',
#  'chrysler:voyager': 'minivan',
#  'chevrolet:hhr_panel': 'suv',
#  'lamborghini:countach': 'car',
#  'gmc:suburban_2500': 'truck',
#  'suzuki:grand_vitara': 'suv',
#  'toyota:xtra': 'truck',
#  'bmw:alpina_b7': 'car',
#  'saab:9000': 'car',
#  'chevrolet:equinox': 'suv',
#  'daewoo:lanos': 'car',
#  'audi:5000cs_quattro': 'car',
#  'ford:festiva': 'car',
#  'bmw:x6': 'suv',
#  'plymouth:reliant': 'car',
#  'land_rover:defender_110': 'suv',
#  'pontiac:vibe': 'car',
#  'dodge:d250_club': 'truck',
#  'gmc:sierra_2500': 'truck',
#  'volvo:850': 'car',
#  'austin:mini_cooper_s': 'car',
#  'ford:escape': 'suv',
#  'plymouth:prowler': 'car',
#  'honda:fcx_clarity': 'car',
#  'ford:galaxie': 'car',
#  'mercedes-benz:r-class': 'suv',
#  'toyota:paseo': 'car',
#  'ford:lightning': 'truck',
#  'isuzu:i-370': 'truck',
#  'chevrolet:malibu_maxx': 'car',
#  'subaru:tribeca': 'suv',
#  'mazda:rx-7': 'car',
#  'hyundai:genesis': 'car',
#  'chrysler:lhs': 'car',
#  'eagle:summit': 'suv',
#  'chevrolet:silverado_hybrid': 'truck',
#  'mazda:cx-7': 'suv',
#  'toyota:highlander': 'suv',
#  'suzuki:x-90': 'suv',
#  'volvo:240': 'car',
#  'volkswagen:r32': 'car',
#  'chevrolet:express_2500': 'minivan',
#  'mazda:626': 'car',
#  'chevrolet:corvair': 'car',
#  'citroen:2cv': 'car',
#  'buick:electra': 'car',
#  'chrysler:prowler': 'car',
#  'ford:f250': 'truck',
#  'mercedes-benz:300sd': 'car',
#  'mercedes-benz:600sl': 'car',
#  'ford:aspire': 'car',
#  'volkswagen:corrado': 'car',
#  'volvo:s90': 'car',
#  'aston_martin:vantage': 'car',
#  'bentley:continental': 'car',
#  'ford:econoline_e150': 'minivan',
#  'suzuki:reno': 'car',
#  'pontiac:sunbird': 'car',
#  'lincoln:continental': 'car',
#  'nissan:300zx': 'car',
#  'acura:zdx': 'car',
#  'nissan:nx': 'car',
#  'maybach:62': 'car',
#  'volvo:960': 'car',
#  'oldsmobile:aurora': 'car',
#  'toyota:t100': 'truck',
#  'jeep:liberty': 'suv',
#  'volvo:v70': 'car',
#  'porsche:944': 'car',
#  'chevrolet:impala': 'car',
#  'mercedes-benz:w201': 'car',
#  'pontiac:gemini': 'car',
#  'nissan:cube': 'car',
#  'foose:hemisfear': 'car',
#  'mercedes-benz:300d': 'car',
#  'dodge:stealth': 'car',
#  'maserati:spyder': 'car',
#  'honda:prelude': 'car',
#  'saab:9-4x': 'suv',
#  'acura:legend': 'car',
#  'mercedes-benz:300e': 'car',
#  'chevrolet:trailblazer': 'suv',
#  'honda:crosstour': 'suv',
#  'geo:storm': 'car',
#  'lexus:lfa': 'car',
#  'mercury:capri': 'car',
#  'aston_martin:v8_vantage': 'car',
#  'ford:windstar': 'minivan',
#  'plymouth:roadrunner': 'car',
#  'audi:quattro': 'car',
#  'volkswagen:golf_iii': 'car',
#  'honda:accord': 'car',
#  'gmc:1500': 'truck',
#  'isuzu:i-290': 'truck',
#  'bmw:600': 'car',
#  'audi:s4': 'car',
#  'bmw:7_series': 'car',
#  'mercury:mystique': 'car',
#  'porsche:cayenne': 'suv',
#  'saab:9-3': 'car',
#  'lexus:lx': 'suv',
#  'hyundai:xg300': 'car',
#  'lexus:rx': 'car',
#  'buick:rendezvous': 'suv',
#  'ford:tempo': 'car',
#  'mini:cooper_clubman': 'car',
#  'chevrolet:caprice_classic': 'car',
#  'gmc:vandura_1500': 'minivan',
#  'toyota:solara': 'car',
#  'ford:econoline_e350': 'minivan',
#  'oldsmobile:cutlass_cruiser': 'car',
#  'mitsubishi:starion': 'car',
#  'toyota:mr2': 'car',
#  'bmw:x6_m': 'suv',
#  'cadillac:srx': 'suv',
#  'mazda:mazdaspeed_3': 'car',
#  'spyker:c8_spyder_wide_body': 'car',
#  'jaguar:xj': 'car',
#  'lincoln:mkx': 'car',
#  'dodge:ram_van_b350': 'minivan',
#  'lincoln:aviator': 'suv',
#  'mercedes-benz:sprinter': 'minivan',
#  'dodge:sprinter': 'minivan',
#  'spyker:c8_laviolette': 'car',
#  'audi:90': 'car',
#  'subaru:justy': 'car',
#  'buick:reatta': 'car',
#  'volkswagen:touareg_2': 'suv',
#  'aptera:type-1h': 'car',
#  'mitsubishi:chariot': 'car',
#  'bmw:m6': 'car',
#  'acura:cl': 'car',
#  'chevrolet:astro': 'minivan',
#  'jaguar:xk_series': 'car',
#  'gmc:rally_wagon_g3500': 'minivan',
#  'eagle:talon': 'car',
#  'hillman:minx_magnificent': 'car',
#  'toyota:land_cruiser': 'suv',
#  'suzuki:sidekick': 'suv',
#  'eagle:vision': 'car',
#  'chevrolet:bel_air': 'car',
#  'infiniti:fx': 'car',
#  'dodge:d350': 'truck',
#  'mercedes-benz:500sel': 'car',
#  'audi:200': 'car',
#  'porsche:924': 'car',
#  'ford:laser': 'car',
#  'honda:odyssey': 'minivan',
#  'mercury:monterey': 'minivan',
#  'volkswagen:phaeton': 'car',
#  'toyota:prius_plug-in': 'car',
#  'dodge:ram_1500': 'truck',
#  'honda:element': 'suv',
#  'mazda:cx-5': 'suv',
#  'dodge:stratus': 'car',
#  'mazda:323': 'car',
#  'mitsubishi:outlander': 'suv',
#  'mazda:mx-6': 'car',
#  'pontiac:g5': 'car',
#  'oldsmobile:98': 'car',
#  'toyota:venza': 'car',
#  'saturn:ion': 'car',
#  'honda:pilot': 'suv',
#  'infiniti:qx56': 'suv',
#  'pontiac:grand_prix': 'car',
#  'hummer:h2_sut': 'suv',
#  'mazda:mazdaspeed6': 'car',
#  'citroen:sm': 'car',
#  'pontiac:montana_sv6': 'minivan',
#  'mitsubishi:galant': 'car',
#  'lincoln:zephyr': 'car',
#  'cadillac:catera': 'car',
#  'cadillac:sixty_special': 'car',
#  'mercury:cougar': 'car',
#  'mitsubishi:precis': 'car',
#  'buick:skyhawk': 'car',
#  'gmc:2500': 'truck',
#  'mercedes-benz:glk-class': 'suv',
#  'hyundai:hed-5': 'car',
#  'jensen:interceptor': 'suv',
#  'ford:ranger': 'truck',
#  'toyota:camry_solara': 'car',
#  'daihatsu:charade': 'car',
#  'volkswagen:riolet': 'car',
#  'bmw:8_series': 'car',
#  'kia:spectra': 'car',
#  'gmc:rally_wagon_2500': 'minivan',
#  'isuzu:i-series': 'truck',
#  'chevrolet:express': 'minivan',
#  'mercury:lynx': 'car',
#  'dodge:ram_van_b250': 'minivan',
#  'ford:country': 'car',
#  'subaru:baja': 'truck',
#  'volkswagen:gti': 'car',
#  'gmc:sonoma_club': 'truck',
#  'ford:five_hundred': 'car',
#  'volkswagen:cc': 'car',
#  'panoz:esperante': 'car',
#  'toyota:4runner': 'suv',
#  'chevrolet:silverado_2500': 'truck',
#  'oldsmobile:custom_cruiser': 'car',
#  'chevrolet:tracker': 'suv',
#  'oldsmobile:toronado': 'car',
#  'land_rover:range_rover': 'suv',
#  'honda:passport': 'suv',
#  'buick:lesabre': 'car',
#  'chevrolet:aveo': 'car',
#  'volkswagen:jetta': 'car',
#  'oldsmobile:bravada': 'suv',
#  'hyundai:excel': 'car',
#  'bentley:continental_super': 'car',
#  'mercury:topaz': 'car',
#  'isuzu:impulse': 'car',
#  'audi:rs4': 'car',
#  'dodge:monaco': 'car',
#  'mitsubishi:tundra': 'truck',
#  'buick:hearse': 'car',
#  'lexus:is': 'car',
#  'kia:forte': 'car',
#  'maybach:57': 'car',
#  'chevrolet:cobalt_ss': 'car',
#  'pontiac:firebird_formula': 'car',
#  'toyota:truck_xtracab_sr5': 'truck',
#  'gmc:safari': 'minivan',
#  'ford:e150': 'truck',
#  'daihatsu:rocky': 'car',
#  'chrysler:sebring': 'car',
#  'toyota:corolla': 'car',
#  'ford:freestar': 'minivan',
#  'audi:4000s': 'car',
#  'mercury:milan': 'car',
#  'nissan:nv3500': 'minivan',
#  'aptera:typ-1': 'car',
#  'infiniti:g35': 'car',
#  'chevrolet:corsica': 'car',
#  'chevrolet:g-series_g10': 'minivan',
#  'pontiac:torrent': 'suv',
#  'kia:sportage': 'suv',
#  'kia:sephia': 'car',
#  'pontiac:1000': 'car',
#  'cadillac:seville': 'car',
#  'chevrolet:1500': 'truck',
#  'honda:del_sol': 'car',
#  'ford:expedition_el': 'suv',
#  'mercedes-benz:w126': 'car',
#  'subaru:xt': 'car',
#  'buick:park_avenue': 'car',
#  'isuzu:stylus': 'car',
#  'jeep:grand_cherokee': 'suv',
#  'toyota:prius_c': 'car',
#  'mercedes-benz:slk-class': 'car',
#  'chrysler:fifth_ave': 'car',
#  'gmc:rally_wagon_3500': 'minivan',
#  'isuzu:axiom': 'suv',
#  'ford:f-series': 'truck',
#  'oldsmobile:intrigue': 'car',
#  'audi:coupe_gt': 'car',
#  'ram:c/v': 'minivan',
#  'suzuki:equator': 'truck',
#  'bmw:525': 'car',
#  'gmc:savana_1500': 'minivan',
#  'gmc:3500_club_coupe': 'truck',
#  'audi:5000cs': 'car',
#  'ford:focus_st': 'car',
#  'ford:f450': 'truck',
#  'kia:sorento': 'suv',
#  'fairthorpe:rockette': 'car',
#  'scion:xd': 'car',
#  'cadillac:deville': 'car',
#  'mazda:miata_mx-5': 'car',
#  'mazda:rx-8': 'car',
#  'porsche:carrera_gt': 'car',
#  'volvo:xc90': 'suv',
#  'pontiac:aztek': 'suv',
#  'mercedes-benz:300ce': 'car',
#  'volkswagen:passat': 'car',
#  'audi:cabriolet': 'car',
#  'chrysler:grand_voyager': 'minivan',
#  ...}

# %%
#types2dir = {}
#for num,x in enumerate(product(colors,class_types)):
#    c = x[0]
#    t = x[1]
#    key = make_key(c,t)
#    types2dir[key] = num
    
types2dir = {}
for num,x in enumerate(class_types):
    types2dir[x] = num

# %%
types2dir
# Out:
# {'car': 0, 'minivan': 3, 'suv': 1, 'truck': 2}

# %%
def outfile_colorbodytype(cleaned,types2dir,car2type):
    color = cleaned['color']
    make = cleaned['make'].replace(' ','_').lower()
    model = cleaned['model'].replace(' ','_').lower()
    fnaem = cleaned['filename']
    make_model_lookup = '{0}:{1}'.format(make,model)
    mm = car2type[make_model_lookup]
    if mm == 'unknown':
        print (cleaned)
    color_body_lookup = '{0}:{1}'.format(color,mm)
    directory = types2dir[color_body_lookup]
    return directory

def outfile_bodytype(cleaned,types2dir,car2type):
    color = cleaned['color']
    make = cleaned['make'].replace(' ','_').lower()
    model = cleaned['model'].replace(' ','_').lower()
    fnaem = cleaned['filename']
    make_model_lookup = '{0}:{1}'.format(make,model)
    mm = car2type[make_model_lookup]
    if mm == 'unknown':
        print (cleaned)
    directory = types2dir[mm]
    return directory

def outfile_color(cleaned,types2dir):
    color = cleaned['color']
    directory = types2dir[color]
    return directory

# %%
af = open(allFiles,'r')

directoryroot = '/local_data/dgrossman/dgCars/{0}'
outdirectory = '/local_data/dgrossman/keras/color/train/{0}/{1}'
for line in tqdm.tqdm(af):
    cleaned = json.loads(line.strip())
    #directory = outfile_outfile_colorbodytype(cleaned,types2dir,car2type)
    #directory = outfile_bodytype(cleaned,types2dir,car2type)
    d = outfile_color(cleaned,color2dir)
    base_name = os.path.basename(cleaned['filename'])
    os.symlink(directoryroot.format(cleaned['filename']),outdirectory.format(d,base_name))
# Out:
# 836555it [00:37, 22362.42it/s]

# %%
#inv_map = {v: k for k, v in a.items()}

# %%
import json

# %%
outfile(cleaned,types2dir,car2type)
# Out:
# 0

# %%
outfile_color(cleaned,color2dir)
# Out:
# 9
